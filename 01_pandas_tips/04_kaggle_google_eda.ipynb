# %% [markdown]
# ## Google App Store EDA

# %% [markdown]
# # Assigment:
# 1. Dowmload tha data.
# 2. Extract data from zip file
# 3. Read the data into python pandas
# 4. check each column
# 5. Define each column in MD Style.

# %% [markdown]
# # Ctril + Shift + p -> Terminal: Select Default Profile (Chose your option (cmd+git bash+ powershell+ windown power shell))

# %%
# import libraries 
import pandas as pd
import ydata_profiling as yd

# %%
# data import
df = pd.read_csv('./data/googleplaystore.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # data import
# ----> 2 df = pd.read_csv('./data/googleplaystore.csv')
#
# NameError: name 'pd' is not defined

# %%
# Run automatic EDA using ydata-profiling library 
profile = yd.ProfileReport(df)
profile.to_file(output_file='./output/04_ydata.googleplaystore.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Run automatic EDA using ydata-profiling library
# ----> 2 profile = yd.ProfileReport(df)
#       3 profile.to_file(output_file='./output/04_ydata.googleplaystore.html')
#
# NameError: name 'yd' is not defined

# %% [markdown]
# # Dataset link : https://www.kaggle.com/datasets/lava18/google-play-store-apps/
# # Apple EDA: https://www.kaggle.com/code/azambukhari/appleeda
# # Github Repository to find codes: https://github.com/AammarTufail/six-months_python_for_data_science-mentorship-program
# # EDA help in

# %%
# Always check the meta data.
