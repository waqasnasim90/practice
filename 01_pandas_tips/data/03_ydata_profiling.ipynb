# %% [markdown]
# # Assigement find out the libraries who is doing libraries.

# %%
# Y-data Profilng defination :  
# Skimpy library defination :

# %% [markdown]
# # Automatic EDA using ydata_profiling

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ydata_profiling as yd

# %%
# Import data from seaborn
df = sns.load_dataset('titanic')

# %%
import os

# Create output directory if it doesn't exist
os.makedirs('output', exist_ok=True)

# ydata profile report
profile = yd.ProfileReport(df)
profile.to_file(output_file='./output/03_ydata.titanic.html')
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00,  2.69it/s]

# %% [markdown]
# # Do it on our Pak Population dataset

# %%
df_pop = pd.read_csv("D:\Waqas\Waqas Learning\Codanics\practice\pandas_tips\data.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\waqas.naseem\AppData\Local\Temp\ipykernel_20724\3279539322.py:1: SyntaxWarning: invalid escape sequence '\W'
#   df_pop = pd.read_csv("D:\Waqas\Waqas Learning\Codanics\practice\pandas_tips\data.csv")

# %%
# ydata profile report
profile = yd.ProfileReport(df_pop)
profile.to_file(output_file='./output/03b_pak_population.titanic.html')
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00,  2.12it/s]
